# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('OnlineRetail.csv', encoding='ISO-8859-1')
df[30000:31000]
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 30000    538839     21539          RED RETROSPOT BUTTER DISH         1
# 30001    538839     21408          SPOTTY PINK DUCK DOORSTOP         1
# 30002    538839     21890  S/6 WOODEN SKITTLES IN COTTON BAG         1
# 30003    538839     20977           36 PENCILS TUBE WOODLAND         1
# 30004    538839     37448    CERAMIC CAKE DESIGN SPOTTED MUG         1
# ...         ...       ...                                ...       ...
# 30995    538886     35924      HANGING FAIRY CAKE DECORATION         6
# 30996    538886     22779         WOODEN OWLS LIGHT GARLAND          4
# 30997    538886     22553             PLASTERS IN TIN SKULLS        12
# 30998    538886     22556     PLASTERS IN TIN CIRCUS PARADE         12
# 30999    538886     21881                     CUTE CATS TAPE        12
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 30000  12/14/2010 13:10       4.95     14606.0  United Kingdom
# 30001  12/14/2010 13:10       4.25     14606.0  United Kingdom
# 30002  12/14/2010 13:10       2.95     14606.0  United Kingdom
# 30003  12/14/2010 13:10       1.25     14606.0  United Kingdom
# 30004  12/14/2010 13:10       1.49     14606.0  United Kingdom
# ...                 ...        ...         ...             ...
# 30995  12/14/2010 16:07       2.10     13846.0  United Kingdom
# 30996  12/14/2010 16:07       4.25     13846.0  United Kingdom
# 30997  12/14/2010 16:07       1.65     13846.0  United Kingdom
# 30998  12/14/2010 16:07       1.65     13846.0  United Kingdom
# 30999  12/14/2010 16:07       0.65     13846.0  United Kingdom
#
# [1000 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# - Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.
# - Tạo cột mới có tên quý –  ‘Previous’ nhận giá trị 1 nếu ngày lập hóa đơn nằm trong các tháng 1,2,3; nhận giá trị 2 nếu ngày lập hóa đơn nằm trong các tháng 4,5,6; nhận giá trị 3 nếu ngày lập hóa đơn nằm trong các tháng 7,8,9;  nhận giá trị 4 nếu ngày lập hóa đơn nằm trong các tháng 10,11,12;
# - Tạo một cột mới có tên ‘Amount’ có giá trị bằng Quantity * UnitPrice
# - Tạo cột mới ‘Discount’ nhận giá trị 10% nếu Country là ‘United Kingdom’ và thuộc quý 4, 5% nếu là ‘France’ ngược lại là 0%.
# - Tạo cột mới ‘Total’ nhận giá trị bằng: Amount – Discount.

# %%
df['Month'] = pd.to_datetime(df['InvoiceDate'], format='%m/%d/%Y %H:%M').dt.month
conditions = [
    (df['Month'] == 1) | (df['Month'] == 2) | (df['Month'] == 3),
    (df['Month'] == 4) | (df['Month'] == 5) | (df['Month'] == 6),
    (df['Month'] == 7) | (df['Month'] == 8) | (df['Month'] == 9)
]
choice_list = [1, 2, 3]

df['Previous'] = np.select(condlist=conditions, choicelist=choice_list, default=4)
df.drop(columns=['Month'], inplace=True)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Previous
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom         4
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom         4
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# ...                 ...        ...         ...             ...       ...
# 541904  12/9/2011 12:50       0.85     12680.0          France         4
# 541905  12/9/2011 12:50       2.10     12680.0          France         4
# 541906  12/9/2011 12:50       4.15     12680.0          France         4
# 541907  12/9/2011 12:50       4.15     12680.0          France         4
# 541908  12/9/2011 12:50       4.95     12680.0          France         4
#
# [541909 rows x 9 columns]

# %%
df['Amount'] = df['Quantity'] * df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Previous  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom         4
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom         4
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# ...                 ...        ...         ...             ...       ...
# 541904  12/9/2011 12:50       0.85     12680.0          France         4
# 541905  12/9/2011 12:50       2.10     12680.0          France         4
# 541906  12/9/2011 12:50       4.15     12680.0          France         4
# 541907  12/9/2011 12:50       4.15     12680.0          France         4
# 541908  12/9/2011 12:50       4.95     12680.0          France         4
#
#         Amount
# 0        15.30
# 1        20.34
# 2        22.00
# 3        20.34
# 4        20.34
# ...        ...
# 541904   10.20
# 541905   12.60
# 541906   16.60
# 541907   16.60
# 541908   14.85
#
# [541909 rows x 10 columns]

# %%
discount_conditions = [
    (df['Country'] == 'United Kingdom') & (df['Previous'] == 4),
    (df['Country'] == 'France')
]
discount_choice_list = ['10%', '5%']
df['Discount'] = np.select(condlist=discount_conditions, choicelist=discount_choice_list, default='0%')

df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Previous  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom         4
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom         4
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# ...                 ...        ...         ...             ...       ...
# 541904  12/9/2011 12:50       0.85     12680.0          France         4
# 541905  12/9/2011 12:50       2.10     12680.0          France         4
# 541906  12/9/2011 12:50       4.15     12680.0          France         4
# 541907  12/9/2011 12:50       4.15     12680.0          France         4
# 541908  12/9/2011 12:50       4.95     12680.0          France         4
#
#         Amount Discount
# 0        15.30      10%
# 1        20.34      10%
# 2        22.00      10%
# 3        20.34      10%
# 4        20.34      10%
# ...        ...      ...
# 541904   10.20       5%
# 541905   12.60       5%
# 541906   16.60       5%
# 541907   16.60       5%
# 541908   14.85       5%
#
# [541909 rows x 11 columns]

# %%
df['temp'] = (df['Discount'].str[0:-1:1]).astype(int)
df['Total'] = df['Amount'] - (df['Amount'] * df['temp'])/100
df.drop(columns=['temp'], inplace=True)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Previous  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom         4
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom         4
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom         4
# ...                 ...        ...         ...             ...       ...
# 541904  12/9/2011 12:50       0.85     12680.0          France         4
# 541905  12/9/2011 12:50       2.10     12680.0          France         4
# 541906  12/9/2011 12:50       4.15     12680.0          France         4
# 541907  12/9/2011 12:50       4.15     12680.0          France         4
# 541908  12/9/2011 12:50       4.95     12680.0          France         4
#
#         Amount Discount    Total
# 0        15.30      10%  13.7700
# 1        20.34      10%  18.3060
# 2        22.00      10%  19.8000
# 3        20.34      10%  18.3060
# 4        20.34      10%  18.3060
# ...        ...      ...      ...
# 541904   10.20       5%   9.6900
# 541905   12.60       5%  11.9700
# 541906   16.60       5%  15.7700
# 541907   16.60       5%  15.7700
# 541908   14.85       5%  14.1075
#
# [541909 rows x 12 columns]
