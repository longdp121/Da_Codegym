# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('house_price_dống-da.xlsx')
df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                title  \
# 0  Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1  Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2  Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 3  Bán nhà 6 tầng mới kinh doanh mặt ngõ 1194 Đườ...
# 4  Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
#
#                                              address  area    price  \
# 0  Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...  50.0  14700.0
# 1  Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...  35.0  12500.0
# 2  Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...  57.0   4200.0
# 3  Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...  62.0  11000.0
# 4   Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội  70.0  36000.0
#
#     postDate land_certificate house_direction balcony_direction  toilet  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1000 non-null   object
#  1   address            1000 non-null   object
#  2   area               994 non-null    float64
#  3   price              944 non-null    float64
#  4   postDate           1000 non-null   datetime64[ns]
#  5   land_certificate   693 non-null    object
#  6   house_direction    44 non-null     object
#  7   balcony_direction  24 non-null     object
#  8   toilet             551 non-null    float64
#  9   bedroom            635 non-null    float64
#  10  floor              376 non-null    float64
#  11  type_of_land       1000 non-null   object
#  12  street_name        808 non-null    object
#  13  ward_name          802 non-null    object
#  14  district_name      1000 non-null   object
# ...

# %% [markdown]
# - Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.
# - Lọc ra các bản ghi bán nhà riêng tại phường Trung liệt hoặc phường Khâm Thiên
# - Lọc các thông tin Địa chỉ, Giá, Hướng nhà, Hướng ban công của các bản ghi có giấy chứng nhận sổ đỏ và có 3 phòng ngủ trở lên.
# - Với mỗi loại nhà đất, tính trung bình cộng giá cũng như giá lớn nhất và giá nhỏ nhất.
# - Tính trung bình cộng số phòng ngủ, số phòng vệ sinh, số tầng của mỗi phường.

# %%
df_by_ward = df[(df['ward_name'] == 'Phường Khâm Thiên') | (df['ward_name'] == 'Phường Trung Liệt')]
df_by_ward.head()
# Out:
#                                                 title  \
# 0   Bán nhà Trần Quang Diệu mới coong đẹp 50m2x6 t...
# 1   Bán nhà mặt phố Tây Sơn - 6 tầng. Kinh doanh t...
# 2   Bán nhà số 36 Đoàn Kết - phố Khâm Thiên - Đống...
# 4   Bán nhà mặt phố Thái Hà 70m2, 5 tầng, 4.5m mặt...
# 19  Bán gấp Tập thể chùa Bộc giá 2,6 tỷ, DT 110m2,...
#
#                                               address   area    price  \
# 0   Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...   50.0  14700.0
# 1   Đường Tây Sơn, Phường Trung Liệt, Đống Đa, Hà...   35.0  12500.0
# 2   Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...   57.0   4200.0
# 4    Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội   70.0  36000.0
# 19  Chùa Bộc, Phường Trung Liệt, Quận Đống Đa, Hà Nội  110.0   2600.0
#
#      postDate land_certificate house_direction balcony_direction  toilet  \
# 0  2021-01-01            Sổ đỏ             NaN               NaN     4.0
# ...

# %%
df_temp = df[(df['land_certificate'] == 'Sổ đỏ') & (df['bedroom'] >= 3)]
#df_temp
df_add_and_direct = df_temp[['address', 'house_direction', 'balcony_direction']]
df_add_and_direct
# Out:
#                                                address house_direction  \
# 0    Đường Trần Quang Diệu, Phường Trung Liệt, Đốn...             NaN
# 2    Số 36 Đoàn Kết, Phố Khâm Thiên, Phường Thổ Qu...             Nam
# 3    Ngõ 1194, Đường Láng, Phường Láng Thượng, Đố...            Đông
# 4     Phố Thái Hà, Phường Trung Liệt, Đống Đa, Hà Nội             NaN
# 5    Phố Chùa Bộc, Phường Quang Trung, Đống Đa, Hà Nội             NaN
# ..                                                 ...             ...
# 989       Phố Xã Đàn, Phường Kim Liên, Đống Đa, Hà Nội             NaN
# 990  Thịnh Quang, Phường Thịnh Quang, Quận Đống Đa,...             NaN
# 991  Thịnh Quang, Phường Thịnh Quang, Quận Đống Đa,...             NaN
# 995  Đường Yên Lãng, Phường Láng Hạ, Đống Đa, Hà...             NaN
# 998  Hồ Văn Chương, Phường Văn Chương, Quận Đống Đa...             NaN
#
#     balcony_direction
# 0                 NaN
# 2                 Nam
# 3            Đông-Nam
# ...

# %%
df_type_mean = df.groupby(['type_of_land'])['price'].mean()
df_type_mean
# Out:
# type_of_land
# Bán nhà mặt phố         38816.227869
# Bán nhà mặt phố\n       77905.654762
# Bán nhà riêng            6052.253968
# Bán nhà riêng\n         10959.577959
# Bất động sản khác       18492.222222
# Bất động sản khác\n     23437.000000
# Chung cư                 2011.864407
# Tập thể, cư xá           2094.637681
# Đất thổ cư              10585.000000
# Name: price, dtype: float64

# %%
df_type_max = df.groupby(['type_of_land'])['price'].max()
df_type_max
# Out:
# type_of_land
# Bán nhà mặt phố          500000.0
# Bán nhà mặt phố\n       3300000.0
# Bán nhà riêng             36000.0
# Bán nhà riêng\n          120000.0
# Bất động sản khác         32000.0
# Bất động sản khác\n       52000.0
# Chung cư                  10000.0
# Tập thể, cư xá             8200.0
# Đất thổ cư                24500.0
# Name: price, dtype: float64

# %%
df_type_min = df.groupby(['type_of_land'])['price'].min()
df_type_min
# Out:
# type_of_land
# Bán nhà mặt phố            4.5
# Bán nhà mặt phố\n       5950.0
# Bán nhà riêng            780.0
# Bán nhà riêng\n         1400.0
# Bất động sản khác         30.0
# Bất động sản khác\n     9870.0
# Chung cư                 530.0
# Tập thể, cư xá           450.0
# Đất thổ cư              3680.0
# Name: price, dtype: float64

# %%
df_ward_mean = df.groupby(['ward_name'])['bedroom', 'toilet'].mean()
df_ward_mean
# Out:
# /tmp/ipykernel_4482/1511392531.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_ward_mean = df.groupby(['ward_name'])['bedroom', 'toilet'].mean()
#                        bedroom    toilet
# ward_name
# Phường Cát Linh       3.300000  3.600000
# Phường Hàng Bột       3.200000  3.321429
# Phường Khâm Thiên     3.384615  2.863636
# Phường Khương Thượng  2.730769  2.375000
# Phường Kim Liên       3.388889  3.000000
# Phường Láng Hạ        4.519231  4.230769
# Phường Láng Thượng    5.071429  4.425532
# Phường Nam Đồng       3.961538  4.166667
# Phường Ngã Tư Sở      3.461538  3.727273
# Phường Phương Liên    3.466667  3.461538
# Phường Phương Mai     2.821429  2.269231
# Phường Quang Trung    3.368421  3.222222
# Phường Quốc Tử Giám   4.000000  4.000000
# Phường Thịnh Quang    3.090909  3.238095
# Phường Thổ Quan       4.000000  4.500000
# Phường Trung Liệt     4.419355  3.693333
# ...
