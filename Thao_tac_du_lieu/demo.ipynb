# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('shopeep_koreantop_clothing_shop_data.csv')
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pk_shop             746 non-null    int64
#  1   date_collected      746 non-null    object
#  2   shopid              746 non-null    int64
#  3   name                746 non-null    object
#  4   join_month          746 non-null    object
#  5   join_day            746 non-null    int64
#  6   join_year           746 non-null    int64
#  7   item_count          746 non-null    int64
#  8   follower_count      746 non-null    int64
#  9   response_time       746 non-null    object
#  10  response_rate       746 non-null    int64
#  11  shop_location       428 non-null    object
#  12  rating_bad          746 non-null    int64
#  13  rating_good         746 non-null    int64
#  14  rating_normal       746 non-null    int64
#  15  rating_star         740 non-null    float64
# ...

# %%
#Lay cot theo ten
# df1 = df.filter(['shop_location'])
# df1
df1 = df[['shop_location']]
df1
# Out:
#                   shop_location
# 0                           NaN
# 1      San Nicolas,Metro Manila
# 2       Pasay City,Metro Manila
# 3          Binondo,Metro Manila
# 4    Caloocan City,Metro Manila
# ..                          ...
# 741          Legazpi City,Albay
# 742                         NaN
# 743                         NaN
# 744        Binondo,Metro Manila
# 745     Pasay City,Metro Manila
#
# [746 rows x 1 columns]

# %%
# Lay nhieu cot theo ten
# df2 = df.filter(['join_month', 'join_day', 'join_year'])
# df2
df2 = df[['join_month', 'join_day', 'join_year']]
df2
# Out:
#     join_month  join_day  join_year
# 0        April        27       2020
# 1    September        25       2020
# 2    September        27       2016
# 3        April        30       2017
# 4      October        18       2016
# ..         ...       ...        ...
# 741        May        22       2021
# 742      March         3       2021
# 743   December        20       2020
# 744     August         2       2017
# 745       June        17       2017
#
# [746 rows x 3 columns]

# %%
# Ttruyen chi so truc tiep der lay nhieu ban ghi
# df3 = df2.filter([0,1 ,2 ,3], axis=0)
# df3

df3 = df2[0:10]
df3
# Out:
#   join_month  join_day  join_year
# 0      April        27       2020
# 1  September        25       2020
# 2  September        27       2016
# 3      April        30       2017
# 4    October        18       2016
# 5      April        26       2021
# 6  September        17       2020
# 7   February        12       2019
# 8  September        22       2020
# 9  September        30       2017

# %%
#Lay thong tin ket hop hang va cot
# df4 = df.filter(['pk_shop', 'rating_bad', 'rating_good'])[:8]
# df4
df4 = df[['pk_shop', 'rating_bad', 'rating_good']][:10]
df4
# Out:
#              pk_shop  rating_bad  rating_good
# 0  20210613254711738         181        17510
# 1  20210613314198143          78         2656
# 2   2021061310377223        4647      1071829
# 3   2021061321407329          44        18959
# 4   2021061311187885         680        39252
# 5  20210613430999411           0            2
# 6  20210613310915998          87        16460
# 7  20210613126018720         354        22350
# 8  20210613312874722         679        28651
# 9   2021061336754442        4524       217241

# %%
#Loc bang ghi co dieu kien
df5 = df[df['join_month'] == 'September']
df5
# Out:
#                pk_shop date_collected     shopid                      name  \
# 1    20210613314198143     2021-06-13  314198143           love.women.shop
# 2     2021061310377223     2021-06-13   10377223             R&O RedOrange
# 6    20210613310915998     2021-06-13  310915998   Yihua Women's Wear Hall
# 8    20210613312874722     2021-06-13  312874722  Shopping Center boutique
# 9     2021061336754442     2021-06-13   36754442           KathrynClothing
# ..                 ...            ...        ...                       ...
# 691   2021070693330925     2021-07-06   93330925         CLASSY CURVE SHOP
# 696  20210706314266101     2021-07-06  314266101  Fat Brothers men's Store
# 710   2021070636222507     2021-07-06   36222507            Beauty Fashion
# 723   2021070610377223     2021-07-06   10377223             R&O RedOrange
# 730   2021070635372816     2021-07-06   35372816                Yvon‘s bag
#
# ...

# %%
#Loc cac ban ghi theo dieu kien phuc (&: and, |: or, ~:except)
#Loc shop open 2021 va co hon 10000 follow

df6 = df[(df['join_year'] == 2021) & (df['follower_count'] > 10000)]
df6
# Out:
#                pk_shop date_collected     shopid                   name  \
# 23   20210613418672464     2021-06-13  418672464                 xuxixi
# 326  20210621419954100     2021-06-21  419954100  Fall in love with you
# 365  20210628418672464     2021-06-28  418672464                 xuxixi
# 389  20210628373953071     2021-06-28  373953071             LK Shop ph
# 558  20210706382931801     2021-07-06  382931801  Stop And Shop Fashion
# 561  20210706373953071     2021-07-06  373953071             LK Shop ph
# 572  20210706418672464     2021-07-06  418672464     XuXi Apparel Store
# 738  20210706419954100     2021-07-06  419954100  Fall in love with you
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 23       April         7       2021         220           10180      09:26:55
# 326      April         9       2021         662           12783      09:01:18
# 365      April         7       2021         220           13768      10:23:37
# ...

# %%
#Loc ban ghi theo dieu kien
#Dung filter, hien thi responetime, responerate cua cac shop cos join_month la Apirl
df7 = df[df['join_month'] == 'April'].filter(['response_time', 'response_rate'])
df7
# Out:
#     response_time  response_rate
# 0        10:13:55             96
# 3        09:10:38             94
# 5        12:33:58             29
# 13       10:43:46             99
# 17       08:05:48             94
# ..            ...            ...
# 724      09:04:02             98
# 735      08:20:51             67
# 737      09:44:25             94
# 738      09:33:28             59
# 739      10:41:36             92
#
# [74 rows x 2 columns]

# %%
#Loc ban ghi su dung query
#Query dung cac toan tu logic and, or, not, cac cau dieu kien dat trong dau ''
#Loc cac shop join nam 2021 va co hon 10k follor
df8 = df.query('(join_year == 2021) and (follower_count > 10000)')
df8
# Out:
#                pk_shop date_collected     shopid                   name  \
# 23   20210613418672464     2021-06-13  418672464                 xuxixi
# 326  20210621419954100     2021-06-21  419954100  Fall in love with you
# 365  20210628418672464     2021-06-28  418672464                 xuxixi
# 389  20210628373953071     2021-06-28  373953071             LK Shop ph
# 558  20210706382931801     2021-07-06  382931801  Stop And Shop Fashion
# 561  20210706373953071     2021-07-06  373953071             LK Shop ph
# 572  20210706418672464     2021-07-06  418672464     XuXi Apparel Store
# 738  20210706419954100     2021-07-06  419954100  Fall in love with you
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# 23       April         7       2021         220           10180      09:26:55
# 326      April         9       2021         662           12783      09:01:18
# 365      April         7       2021         220           13768      10:23:37
# ...
