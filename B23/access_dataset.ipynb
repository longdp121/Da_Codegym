# %%
import pandas as pd

# %%
df = pd.read_csv('FoodPrice_in_Turkey.csv')
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ### iloc

# %%
df.iloc[3]
# Out:
# Place          National Average
# ProductId                    52
# ProductName       Rice - Retail
# UmId                          5
# UmName                       KG
# Month                        12
# Year                       2013
# Price                    5.1337
# Name: 3, dtype: object

# %%
df.iloc[3:10]
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
# 8  National Average         52  Rice - Retail     5     KG      6  2014
# 9  National Average         52  Rice - Retail     5     KG      7  2014
#
#     Price
# 3  5.1337
# 4  5.5099
# 5  5.8146
# 6  6.0014
# 7  6.3202
# 8  6.6019
# 9  6.6503

# %%
df.iloc[[1, 3, 5,7]]
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
#
#     Price
# 1  4.5786
# 3  5.1337
# 5  5.8146
# 7  6.3202

# %%
df.iloc[:, -1]  #acess to whole last column
# Out:
# 0        4.4920
# 1        4.5786
# 2        4.7865
# 3        5.1337
# 4        5.5099
#          ...
# 7376    47.9040
# 7377    49.1176
# 7378    50.8347
# 7379    51.7985
# 7380    51.6071
# Name: Price, Length: 7381, dtype: float64

# %%
df.iloc[:, 2:5]
# Out:
#                   ProductName  UmId UmName
# 0               Rice - Retail     5     KG
# 1               Rice - Retail     5     KG
# 2               Rice - Retail     5     KG
# 3               Rice - Retail     5     KG
# 4               Rice - Retail     5     KG
# ...                       ...   ...    ...
# 7376  Cocoa (powder) - Retail     5     KG
# 7377  Cocoa (powder) - Retail     5     KG
# 7378  Cocoa (powder) - Retail     5     KG
# 7379  Cocoa (powder) - Retail     5     KG
# 7380  Cocoa (powder) - Retail     5     KG
#
# [7381 rows x 3 columns]

# %%
df.iloc[1:5, 2:5]
# Out:
#      ProductName  UmId UmName
# 1  Rice - Retail     5     KG
# 2  Rice - Retail     5     KG
# 3  Rice - Retail     5     KG
# 4  Rice - Retail     5     KG

# %%
df.iloc[1, -1]
# Out:
# 4.5786

# %% [markdown]
# ### loc

# %%
df.loc[1:2]
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
#
#     Price
# 1  4.5786
# 2  4.7865

# %%
df.loc[1:5, 'Place']
# Out:
# 1    National Average
# 2    National Average
# 3    National Average
# 4    National Average
# 5    National Average
# Name: Place, dtype: object

# %%
df.info()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB
#       Place  ProductId              ProductName  UmId UmName  Month  Year  \
# 7376  Izmir        502  Cocoa (powder) - Retail     5     KG      8  2019
# 7377  Izmir        502  Cocoa (powder) - Retail     5     KG      9  2019
# 7378  Izmir        502  Cocoa (powder) - Retail     5     KG     10  2019
# 7379  Izmir        502  Cocoa (powder) - Retail     5     KG     11  2019
# ...

# %%
df.loc[df.shape[0] - 1, ['Month', 'Year']]
# Out:
# Month      12
# Year     2019
# Name: 7380, dtype: object

# %%
df.loc[3, 'Price']
# Out:
# 5.1337

# %%
df.loc[df.Year >= 2019]
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 54    National Average         52            Rice - Retail     5     KG
# 55    National Average         52            Rice - Retail     5     KG
# 56    National Average         52            Rice - Retail     5     KG
# 57    National Average         52            Rice - Retail     5     KG
# 58    National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 54        1  2019   8.4275
# 55        2  2019   8.7656
# ...

# %% [markdown]
# ### Replace in df

# %%
df.replace('Rice - Retail', False, inplace=True)
df.head()
# Out:
#               Place  ProductId ProductName  UmId UmName  Month  Year   Price
# 0  National Average         52       False     5     KG      5  2013  4.4920
# 1  National Average         52       False     5     KG      6  2013  4.5786
# 2  National Average         52       False     5     KG     11  2013  4.7865
# 3  National Average         52       False     5     KG     12  2013  5.1337
# 4  National Average         52       False     5     KG      1  2014  5.5099

# %%
df.replace(52, 'Nam muoi hai', inplace=True)
df.head()
# Out:
#               Place     ProductId ProductName  UmId UmName  Month  Year  \
# 0  National Average  Nam muoi hai       False     5     KG      5  2013
# 1  National Average  Nam muoi hai       False     5     KG      6  2013
# 2  National Average  Nam muoi hai       False     5     KG     11  2013
# 3  National Average  Nam muoi hai       False     5     KG     12  2013
# 4  National Average  Nam muoi hai       False     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df['Year'].replace(2013, 'Nam 2013 sau cong nguyen', inplace=True)
df.head()
# Out:
#               Place     ProductId ProductName  UmId UmName  Month  \
# 0  National Average  Nam muoi hai       False     5     KG      5
# 1  National Average  Nam muoi hai       False     5     KG      6
# 2  National Average  Nam muoi hai       False     5     KG     11
# 3  National Average  Nam muoi hai       False     5     KG     12
# 4  National Average  Nam muoi hai       False     5     KG      1
#
#                        Year   Price
# 0  Nam 2013 sau cong nguyen  4.4920
# 1  Nam 2013 sau cong nguyen  4.5786
# 2  Nam 2013 sau cong nguyen  4.7865
# 3  Nam 2013 sau cong nguyen  5.1337
# 4                      2014  5.5099
