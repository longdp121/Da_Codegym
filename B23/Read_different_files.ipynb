# %%
import pandas as pd

# %% [markdown]
# ### Read csv file

# %%
df_csv = pd.read_csv('FoodPrice_in_Turkey.csv', sep=',')
df_csv.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ### Read excel file

# %%
df_excel = pd.read_excel('FoodPrice_in_Turkey.xls')
df_excel.head()
# Out:
#    Unnamed: 0             Place  ProductId    ProductName  UmId UmName  Month  \
# 0           0  National Average         52  Rice - Retail     5     KG      5
# 1           1  National Average         52  Rice - Retail     5     KG      6
# 2           2  National Average         52  Rice - Retail     5     KG     11
# 3           3  National Average         52  Rice - Retail     5     KG     12
# 4           4  National Average         52  Rice - Retail     5     KG      1
#
#    Year   Price
# 0  2013  4.4920
# 1  2013  4.5786
# 2  2013  4.7865
# 3  2013  5.1337
# 4  2014  5.5099

# %% [markdown]
# ### Read json file

# %%
df_json = pd.read_json('FoodPrice_in_Turkey.json')
df_json.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ### Read hdf5 file

# %%
df_hdf5 = pd.read_hdf('FoodPrice_in_Turkey.hdf')
df_hdf5.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# ### Read html file

# %%
df_html = pd.read_html('FoodPrice_in_Turkey.html')
print(len(df_html))
df_html[0].head()
# Out:
# 1
#    Unnamed: 0             Place  ProductId    ProductName  UmId UmName  Month  \
# 0           0  National Average         52  Rice - Retail     5     KG      5
# 1           1  National Average         52  Rice - Retail     5     KG      6
# 2           2  National Average         52  Rice - Retail     5     KG     11
# 3           3  National Average         52  Rice - Retail     5     KG     12
# 4           4  National Average         52  Rice - Retail     5     KG      1
#
#    Year   Price
# 0  2013  4.4920
# 1  2013  4.5786
# 2  2013  4.7865
# 3  2013  5.1337
# 4  2014  5.5099
