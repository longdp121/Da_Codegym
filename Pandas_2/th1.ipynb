# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FoodPrice_in_Turkey.csv')
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
# Drop duplicate ID
df = df.drop_duplicates('ProductId', keep='last').reset_index(drop=True)
df
# Out:
#                Place  ProductId  \
# 0   National Average        176
# 1   National Average        212
# 2   National Average        229
# 3   National Average        233
# 4   National Average        384
# 5   National Average        465
# 6              Izmir         52
# 7              Izmir         58
# 8              Izmir         66
# 9              Izmir         83
# 10             Izmir         92
# 11             Izmir         94
# 12             Izmir         97
# 13             Izmir        105
# 14             Izmir        108
# 15             Izmir        112
# 16             Izmir        114
# 17             Izmir        119
# 18             Izmir        124
# 19             Izmir        151
# 20             Izmir        173
# 21             Izmir        181
# 22             Izmir        183
# 23             Izmir        184
# 24             Izmir        185
# 25             Izmir        209
# 26             Izmir        231
# 27             Izmir        239
# ...

# %%
#Product table
df_pr = df[['ProductId', 'ProductName', 'UmId', 'UmName']]
df_pr
# Out:
#     ProductId                                        ProductName  UmId  \
# 0         176                               Tea (green) - Retail    33
# 1         212                         Peas (green, dry) - Retail     5
# 2         229                              Apples (red) - Retail     5
# 3         233                    Cucumbers (greenhouse) - Retail     5
# 4         384                              Bread (pita) - Retail     5
# 5         465  Wage (non-qualified labour, non-agricultural) ...    51
# 6          52                                      Rice - Retail     5
# 7          58                               Wheat flour - Retail     5
# 8          66                             Beans (white) - Retail     5
# 9          83                                  Potatoes - Retail     5
# 10         92                                      Eggs - Retail    33
# 11         94                            Meat (chicken) - Retail     5
# ...

# %%
#Price table
df_price = df[['Price', 'ProductId']]
df_price

df_price_10 = df.loc[0:10, ['Price', 'ProductId']]
df_price_10
# Out:
#       Price  ProductId
# 0    4.6500        176
# 1    3.2900        212
# 2    2.8300        229
# 3    4.2400        233
# 4    2.4800        384
# 5   46.8000        465
# 6   10.2803         52
# 7    4.2703         58
# 8   13.0975         66
# 9    2.0924         83
# 10   0.6301         92

# %%
df_price = pd.merge(df_price, df_pr, on='ProductId')
df_price
# Out:
#        Price  ProductId                                        ProductName  \
# 0     4.6500        176                               Tea (green) - Retail
# 1     3.2900        212                         Peas (green, dry) - Retail
# 2     2.8300        229                              Apples (red) - Retail
# 3     4.2400        233                    Cucumbers (greenhouse) - Retail
# 4     2.4800        384                              Bread (pita) - Retail
# 5    46.8000        465  Wage (non-qualified labour, non-agricultural) ...
# 6    10.2803         52                                      Rice - Retail
# 7     4.2703         58                               Wheat flour - Retail
# 8    13.0975         66                             Beans (white) - Retail
# 9     2.0924         83                                  Potatoes - Retail
# 10    0.6301         92                                      Eggs - Retail
# ...
